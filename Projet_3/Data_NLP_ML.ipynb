# %%
# import des librairies
import pandas as pd
import json
import requests
import numpy as np

# %% [markdown]
# # Création d'un data frame contenant les informations des hotels pour le NLP et le ML

# %%
# Variable contenant le ficher json de "base" où je peux récupérer un morceau du chemin pour chacun des hotels
url_hotel = "https://raw.githubusercontent.com/JulienMhtt/Projets/main/Projet_3/flux_hebergements_hdf/index.json"
# Requetage de la base de données
r_hotel = requests.get(url_hotel)
# Variable contenant le fichier json (une liste)
data_hotel = r_hotel.json()

# Création d'un data frame vite pour recevoir les données des hotels par la suite
df_all_hotel = pd.DataFrame()

# Création d'un dataframe ide pour récupérer les dataframes de chaques pages
dfs_verif = pd.DataFrame()

# Initialisation d'une boucle de longeur 10 pour obtenir un échantillon
for file in range(50):
    # variable contenant la base du chemin vers la base de donnée
    base = "https://raw.githubusercontent.com/JulienMhtt/Projets/main/Projet_3/flux_hebergements_hdf/objects/"
    # url complète composé de la base de l'url et de la seconde partie venant de data
    url_file = base + data_hotel[file]["file"]
    #print(url_file)
    # Requetage de la base de données
    r_file = requests.get(url_file)
    # Variable contenant le fichier json (un dictionnaire)
    data_file = r_file.json()
    # Variable contenant le fichier json tranformé en data frame
    df = pd.json_normalize(data_file)#[["dc:identifier", "@type", "rdfs:comment.fr"]]
    
    # Vérifications
    if "dc:identifier" in df.columns and "@type" in df.columns and "rdfs:comment.fr" in df.columns:
        df = df[["dc:identifier", "@type", "rdfs:comment.fr"]]

        # Utilisez concat à la place de append
        dfs_verif = pd.concat([dfs_verif, df], ignore_index=True)

           
"""   
# A VOIR PLUS TARD
    df["shortDescription.fr"] = pd.json_normalize(data_file, record_path="hasDescription")[["shortDescription.fr"]]
    # Ajout du dataframe à la liste de stockage
    dfs_hotel.append(df)
"""

# Fonction pour extraire les chaines de caractères des listes    
def extraction(valeur):
    if type(valeur) == list:
        valeur = ' '.join(valeur)  # joindre les éléments de la liste avec un espace
        return valeur
    else:
        return valeur
    
# Application de la fonction sur tout le dataframe

dfs_verif = dfs_verif.applymap(extraction)

# Extraction de la première catégorie de @type

df_type_split = dfs_verif["@type"].str.split(" ", expand=True)
dfs_verif = pd.concat([dfs_verif, df_type_split.iloc[:,0]], axis=1)

dfs_verif
# Out:
#    dc:identifier                                              @type  \
# 0        6048882  schema:Accommodation schema:FoodEstablishment ...
# 1        6048875  schema:Accommodation schema:FoodEstablishment ...
# 2        6048867  schema:Accommodation schema:Hotel schema:Lodgi...
# 3        6051608  schema:Accommodation schema:BedAndBreakfast sc...
# 4        6057862  schema:Accommodation schema:LodgingBusiness Ac...
# 5        6051483  schema:Accommodation schema:LodgingBusiness Ac...
# 6        6048870  schema:Accommodation schema:Hotel schema:Lodgi...
# 7        6051515  schema:Accommodation schema:LodgingBusiness Ac...
# 8        6051477  schema:Accommodation schema:BedAndBreakfast sc...
# 9        6048873  schema:Accommodation schema:Hotel schema:Lodgi...
# 10       6051520  schema:Accommodation schema:LodgingBusiness Ac...
# 11       6057877  schema:Accommodation schema:LodgingBusiness Ac...
# 12       6057866  schema:Accommodation schema:LodgingBusiness Ac...
# 13       6057854  schema:Accommodation schema:LodgingBusiness Ac...
# 14       6057874  schema:Accommodation schema:LodgingBusiness Ac...
# 15       6057868  schema:Accommodation schema:LodgingBusiness Ac...
# 16       6048874  schema:Accommodation schema:Hotel schema:Lodgi...
# 17       6057858  schema:Accommodation schema:LodgingBusiness Ac...
# 18       6051476  schema:Accommodation schema:BedAndBreakfast sc...
# 19       6048879  schema:Accommodation schema:Hotel schema:Lodgi...
# 20       6057852  schema:Accommodation schema:LodgingBusiness Ac...
# 21       6051680  schema:Accommodation schema:BedAndBreakfast sc...
# 22       6051474  schema:Accommodation schema:LodgingBusiness Ac...
# 23       6057871  schema:Accommodation schema:LodgingBusiness Ac...
# 24       6048885  schema:Accommodation schema:FoodEstablishment ...
# 25       6051532  schema:Accommodation schema:LodgingBusiness Ac...
# 26       6057879  schema:Accommodation schema:LodgingBusiness Ac...
# 27       6051625  schema:Accommodation schema:LodgingBusiness Ac...
# 28       6057863  schema:Accommodation schema:LodgingBusiness Ac...
# 29       6048868  schema:Accommodation schema:FoodEstablishment ...
# 30       6406205  schema:Accommodation schema:LodgingBusiness Ac...
# 31       6057855  schema:Accommodation schema:LodgingBusiness Ac...
# 32       6057870  schema:Accommodation schema:LodgingBusiness Ac...
# 33       6048884  schema:Accommodation schema:FoodEstablishment ...
# 34       6051533  schema:Accommodation schema:LodgingBusiness Ac...
# 35       6057853  schema:Accommodation schema:LodgingBusiness Ac...
# 36       6048881  schema:Accommodation schema:FoodEstablishment ...
# 37         79462  schema:Accommodation schema:LodgingBusiness Ac...
#
#                                       rdfs:comment.fr                     0
# 0   L’hôtel LA TOUR DES LYS vous accueille depuis ...  schema:Accommodation
# 1   Un hôtel de charme 3 étoiles, dans un château ...  schema:Accommodation
# 2   Magda en charge de la Direction ainsi que tout...  schema:Accommodation
# 3   Des chambres d’hôtes à la ferme à Solre-le-Châ...  schema:Accommodation
# 4   Camping est situé au calme en lisière de la fo...  schema:Accommodation
# 5   Dans le joli village de Ferrière la Petite, Cl...  schema:Accommodation
# 6   Offrez-vous une parenthèse paisible dans cet é...  schema:Accommodation
# 7   Janine vous accueille dans son gîte situé dans...  schema:Accommodation
# 8   En plein bocage avesnois, vous serez accueilli...  schema:Accommodation
# 9   L'hôtel est situé à 200 m de la Gare, Idéal po...  schema:Accommodation
# 10  En plein cœur du bocage avesnois, à Prisches, ...  schema:Accommodation
# 11  Ce camping de 100 emplacements offre de nombre...  schema:Accommodation
# 12  Roselyne, Bruno et Guillaume vous accueillent ...  schema:Accommodation
# 13        Camping situé en plein coeur de l'Avesnois.  schema:Accommodation
# 14  Profitez de ce camping naturiste pour vous res...  schema:Accommodation
# 15  L'Étape de la Pierre Bleue abrite le camping L...  schema:Accommodation
# 16  Hôtel 3 étoiles situé en lisière de la forêt e...  schema:Accommodation
# 17  Situé au coeur de la cité fortifiée du Quesnoy...  schema:Accommodation
# 18  Située au cœur du Parc Naturel Régional de l’A...  schema:Accommodation
# 19  L'hôtel Première Classe de Maubeuge vous propo...  schema:Accommodation
# 20                      Ressourcez-vous au bol d’air.  schema:Accommodation
# 21  Une ferme avesnoise, avec ânes et moutons, vou...  schema:Accommodation
# 22  Janine et son mari vous accueillent dans un an...  schema:Accommodation
# 23  Le camping municipal est situé dans le petit v...  schema:Accommodation
# 24  L'hôtel "Les Charmilles de Mormal"  vous accue...  schema:Accommodation
# 25  Au bout d’un chemin, en plein cœur du Parc Nat...  schema:Accommodation
# 26  Camping 3* situé dans un cadre verdoyant à pro...  schema:Accommodation
# 27  À quelques pas de la frontière belge, Karine v...  schema:Accommodation
# 28  Envie de passer des vacances dans la bonne hum...  schema:Accommodation
# 29  Le BEST WESTERN l'Atelier 117 Hotel & Restaura...  schema:Accommodation
# 30  Dans l'ancienne gare de Ferrière la Grande ent...  schema:Accommodation
# 31  Camping à la ferme à 8 minutes du Val Joly, po...  schema:Accommodation
# 32  Le camping se situe dans un lieu boisé, bordé ...  schema:Accommodation
# 33  La famille Herriche vous accueille dans leur h...  schema:Accommodation
# 34  Au bout d’un chemin, en plein cœur du Parc Nat...  schema:Accommodation
# 35  Le camping est situé dans le parc naturel régi...  schema:Accommodation
# 36  Toute l'équipe vous accueille dans un cadre so...  schema:Accommodation
# 37  Appartement meublé très confortable, spacieux ...  schema:Accommodation

# %% [markdown]
# ## préparation de la colonne rdfs:comment.fr pour son utilisation dans le ML

# %%
import nltk
nltk.download('popular')
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package omw to /Users/julien/nltk_data...
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# True

# %%
import spacy
import string
from nltk.tokenize.punkt import FreqDist
import re

nlp = spacy.load('fr_core_news_lg')

def clean(sentence):
    
  '''
  This function 'clean' takes a single input 'sentence', a string, and performs several operations to 'clean' the text.

  These operations are:
  1. Removing punctuation using a regular expression.
  2. Tokenizing the sentence into individual words.
  3. Removing English stopwords.
  4. Joining the remaining words back into a sentence.
  5. Lemmatizing the sentence using the Spacy English language model.

  The function returns the cleaned, lemmatized sentence as a single string.
  '''

  sentence_no_punct = re.sub(r'[^\w\s]', '', sentence)

  # transform sentence into token
  sentence_no_punct = nltk.word_tokenize(sentence_no_punct.lower())

  # list stopwords we wanna get rid off
  stop_words = set(nltk.corpus.stopwords.words("french"))

  # Get tokens without stopwords and puntuation
  sentence_clean = []
  for words in sentence_no_punct:
    if words not in stop_words:
      sentence_clean.append(words)

  # Transform into str
  sentence_clean_str = ' '.join(sentence_clean)

  # Process the text with Spacy
  sentence_clean_str_spacy = nlp(sentence_clean_str)

  sentence_clean_str_spacy_lemmatized = [token.lemma_ for token in sentence_clean_str_spacy]
  #print(sentence_clean)
  return ' '.join(sentence_clean_str_spacy_lemmatized)

# %%
test = clean(dfs_verif["rdfs:comment.fr"][0])

# %%
for word in test:
    print(word)
# Out:
# l
# h
# ô
# t
# e
# l
#
# t
# o
# u
# r
#
# l
# y
# s
#
# a
# c
# c
# u
# e
# i
# l
# l
# i
# r
#
# d
# e
# p
# u
# i
# s
#
# 2
# 0
# 1
# 0
#
# é
# t
# a
# b
# l
# i
# s
# s
# e
# m
# e
# n
# t
#
# d
# e
# u
# x
#
# f
# r
# o
# n
# t
# i
# è
# r
# e
#
# b
# e
# l
# g
# e
#
# m
# a
# u
# b
# e
# u
# g
# e

# %% [markdown]
# # Création d'un data frame contenant les informations des restaurants pour le NLP et le ML   POUR PLUS TARD

# %%
# Variable contenant le ficher json de "base" où je peux récupérer un mroceau du chemin pour chacun des hotels
url_resto = "https://raw.githubusercontent.com/JulienMhtt/Projets/main/Projet_3/flux_restaurants_hdf/index.json"
# Requetage de la base de données
r_resto = requests.get(url_resto)
# Variable contenant le fichier json (une liste)
data_resto = r_resto.json()

# Création d'un data frame vite pour recevoir les données des hotels par la suite
df_all_resto = pd.DataFrame()

# Création d'une liste pour stocker les differents data frame récupéré dans la boucle
dfs_resto = []

# Initialisation d'une boucle de longeur 10 pour obtenir un échantillon
for file in range(10):
    # variable contenant la base du chemin vers la base de donnée
    base = "https://raw.githubusercontent.com/JulienMhtt/Projets/main/Projet_3/flux_restaurants_hdf/objects/"
    # url complète composé de la base de l'url et de la seconde partie venant de data
    url_file = base + data_resto[file]["file"]
    # Requetage de la base de données
    r_file = requests.get(url_file)
    # Variable contenant le fichier json (un dictionnaire)
    data_file = r_file.json()
    # Variable contenant le fichier json tranformé en data frame
    df = pd.json_normalize(data_file)[["dc:identifier", "@type", "rdfs:comment.fr"]]
    df["shortDescription.fr"] = pd.json_normalize(data_file, record_path="hasDescription")[["shortDescription.fr"]]
    # Ajout du dataframe à la liste de stockage
    dfs_resto.append(df)

# Fonction pour extraire les chaines de caractères des listes    
def extraction(valeur):
    if type(valeur) == list:
        valeur = ' '.join(valeur)  # joindre les éléments de la liste avec un espace
        return valeur
    else:
        return valeur
    
# Concaténation de la liste contenant tous les data frame et le data frame vide
df_all_resto = pd.concat(dfs_resto)
df_all_resto = df_all_resto.applymap(extraction)
df_all_resto
# Out:
#   dc:identifier                                              @type  \
# 0       6048677  schema:FoodEstablishment FoodEstablishment Pla...
# 0       6048787  schema:FoodEstablishment FoodEstablishment Pla...
# 0       6048799  schema:FoodEstablishment FoodEstablishment Pla...
# 0       6048789  schema:FoodEstablishment FoodEstablishment Pla...
# 0       6048763  schema:FoodEstablishment FoodEstablishment Pla...
# 0       6048673  schema:FoodEstablishment FoodEstablishment Pla...
# 0       6048784  schema:FoodEstablishment FoodEstablishment Pla...
# 0       6048709  schema:FoodEstablishment FoodEstablishment Pla...
# 0       6048700  schema:FoodEstablishment FoodEstablishment Pla...
# 0       6048882  schema:Accommodation schema:FoodEstablishment ...
#
#                                      rdfs:comment.fr  \
# 0  Poussez la porte de cet estaminet, où Dominiqu...
# 0  Mikael vous accueille dans son établissement e...
# 0  Dans un écrin vaste et très chaleureux, Fabric...
# 0  Une ferme-auberge au cadre typique en plein cœ...
# 0  Idéalement située au cœur de la station du Val...
# 0  Géraldine vous accueille au cœur de la Station...
# 0  Les Vergers Tellier vous proposent de venir pa...
# 0  L’Hostellerie du marché vous accueille dans le...
# 0  Dans la « rue commerçante » du ValJoly, idéale...
# 0  L’hôtel LA TOUR DES LYS vous accueille depuis ...
#
#                                  shortDescription.fr
# 0  Poussez la porte de cet estaminet, où Dominiqu...
# 0  Mikael vous accueille dans son établissement e...
# 0  Dans un écrin vaste et très chaleureux, Fabric...
# 0  Une ferme-auberge au cadre typique en plein cœ...
# 0  Idéalement située au cœur de la station du Val...
# 0  Géraldine vous accueille au cœur de la Station...
# 0  Les Vergers Tellier vous proposent de venir pa...
# 0  L’Hostellerie du marché vous accueille dans le...
# 0  Dans la « rue commerçante » du ValJoly, idéale...
# 0  L’hôtel LA TOUR DES LYS vous accueille depuis ...
