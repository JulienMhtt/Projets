# %%
# import des librairies
import pandas as pd
import json
import requests
import numpy as np

# %% [markdown]
# # Création d'un data frame contenant les informations des hotels pour le NLP et le ML

# %%
# Variable contenant le ficher json de "base" où je peux récupérer un morceau du chemin pour chacun des hotels
url_hotel = "https://raw.githubusercontent.com/JulienMhtt/Projets/main/Projet_3/flux_hebergements_hdf/index.json"
# Requetage de la base de données
r_hotel = requests.get(url_hotel)
# Variable contenant le fichier json (une liste)
data_hotel = r_hotel.json()

# Création d'un data frame vite pour recevoir les données des hotels par la suite
df_all_hotel = pd.DataFrame()

# Création d'un dataframe ide pour récupérer les dataframes de chaques pages
dfs_verif = pd.DataFrame()

# Initialisation d'une boucle de longeur 10 pour obtenir un échantillon
for file in range(100):
    # variable contenant la base du chemin vers la base de donnée
    base = "https://raw.githubusercontent.com/JulienMhtt/Projets/main/Projet_3/flux_hebergements_hdf/objects/"
    # url complète composé de la base de l'url et de la seconde partie venant de data
    url_file = base + data_hotel[file]["file"]
    # Requetage de la base de données
    r_file = requests.get(url_file)
    # Variable contenant le fichier json (un dictionnaire)
    data_file = r_file.json()
    # Variable contenant le fichier json tranformé en data frame
    df = pd.json_normalize(data_file, errors='ignore')
      
    
    # Vérifier si la clé "rdfs:comment.fr" est présente dans le DataFrame
    if "rdfs:comment.fr" in df.columns:
        # La clé est présente, extraire la valeur
        df["rdfs:comment.fr"] = df["rdfs:comment.fr"]
    else:
        # La clé est absente, assigner une valeur par défaut
        df["rdfs:comment.fr"] = None

    # Sélectionner les colonnes souhaitées
    df = df[["dc:identifier", "@type", "rdfs:comment.fr"]]

    
    # Variable contenant le fichier json tranformé en data frame
    df2 = pd.json_normalize(data_file,
                      record_path="hasDescription", ##### UNE EXCEPTION POUR LUI ######
                      meta="dc:identifier",
                       errors='ignore')

    # Vérifier si la clé "rdfs:comment.fr" est présente dans le DataFrame
    if "dc:description.fr" in df2.columns:
        # La clé est présente, extraire la valeur
        df2["dc:description.fr"] = df2["dc:description.fr"]
    else:
        # La clé est absente, assigner une valeur par défaut
        df2["dc:description.fr"] = None


    df2 = df2[["dc:identifier", "dc:description.fr"]]
    
    # jointure des 2 dataframe sur l'identifiant unique
    df_full = pd.merge(df, df2, on="dc:identifier")

    dfs_verif = pd.concat([dfs_verif, df_full], axis=0)



# Fonction pour extraire les chaines de caractères des listes    
def extraction(valeur):
    if type(valeur) == list:
        valeur = ' '.join(valeur)  # joindre les éléments de la liste avec un espace
        return valeur
    else:
        return valeur
    
# Application de la fonction sur tout le dataframe
dfs_verif = dfs_verif.applymap(extraction)

# Extraction de la première catégorie de @type
df_type_split = dfs_verif["@type"].str.split(" ", expand=True)
dfs_verif = pd.concat([dfs_verif, df_type_split.iloc[:]], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/io/json/_normalize.py:399, in _json_normalize.<locals>._pull_field(js, spec, extract_record)
#     398     else:
# --> 399         result = result[spec]
#     400 except KeyError as e:
#
# KeyError: 'hasDescription'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 41
#      37 df = df[["dc:identifier", "@type", "rdfs:comment.fr"]]
#      40 # Variable contenant le fichier json tranformé en data frame
# ---> 41 df2 = pd.json_normalize(data_file,
#      42                   record_path="hasDescription",
#      43                   meta="dc:identifier",
#      44                    errors='ignore')
#      46 # Vérifier si la clé "rdfs:comment.fr" est présente dans le DataFrame
#      47 if "dc:description.fr" in df2.columns:
#      48     # La clé est présente, extraire la valeur
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/io/json/_normalize.py:518, in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     515                 meta_vals[key].append(meta_val)
#     516             records.extend(recs)
# --> 518 _recursive_extract(data, record_path, {}, level=0)
#     520 result = DataFrame(records)
#     522 if record_prefix is not None:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/io/json/_normalize.py:500, in _json_normalize.<locals>._recursive_extract(data, path, seen_meta, level)
#     498 else:
#     499     for obj in data:
# --> 500         recs = _pull_records(obj, path[0])
#     501         recs = [
#     502             nested_to_record(r, sep=sep, max_level=max_level)
#     503             if isinstance(r, dict)
#     504             else r
#     505             for r in recs
#     506         ]
#     508         # For repeating the metadata later
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/io/json/_normalize.py:422, in _json_normalize.<locals>._pull_records(js, spec)
#     416 def _pull_records(js: dict[str, Any], spec: list | str) -> list:
#     417     """
#     418     Internal function to pull field for records, and similar to
#     419     _pull_field, but require to return list. And will raise error
#     420     if has non iterable value.
#     421     """
# --> 422     result = _pull_field(js, spec, extract_record=True)
#     424     # GH 31507 GH 30145, GH 26284 if result is not list, raise TypeError if not
#     425     # null, otherwise return an empty list
#     426     if not isinstance(result, list):
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/io/json/_normalize.py:402, in _json_normalize.<locals>._pull_field(js, spec, extract_record)
#     400 except KeyError as e:
#     401     if extract_record:
# --> 402         raise KeyError(
#     403             f"Key {e} not found. If specifying a record_path, all elements of "
#     404             f"data should have the path."
#     405         ) from e
#     406     elif errors == "ignore":
#     407         return np.nan
#
# KeyError: "Key 'hasDescription' not found. If specifying a record_path, all elements of data should have the path."

# %%
dfs_verif
# Out:
#   dc:identifier                                              @type  \
# 0       6048882  schema:Accommodation schema:FoodEstablishment ...
# 0       6048875  schema:Accommodation schema:FoodEstablishment ...
# 0       6048867  schema:Accommodation schema:Hotel schema:Lodgi...
# 0       6051608  schema:Accommodation schema:BedAndBreakfast sc...
# 0       6057862  schema:Accommodation schema:LodgingBusiness Ac...
# 0       6051483  schema:Accommodation schema:LodgingBusiness Ac...
# 0       6048870  schema:Accommodation schema:Hotel schema:Lodgi...
# 0       6051515  schema:Accommodation schema:LodgingBusiness Ac...
# 0       6051477  schema:Accommodation schema:BedAndBreakfast sc...
# 0       6048873  schema:Accommodation schema:Hotel schema:Lodgi...
# 0       6051520  schema:Accommodation schema:LodgingBusiness Ac...
# 0       6057877  schema:Accommodation schema:LodgingBusiness Ac...
# 0       6057866  schema:Accommodation schema:LodgingBusiness Ac...
# 0       6057854  schema:Accommodation schema:LodgingBusiness Ac...
# 0       6057874  schema:Accommodation schema:LodgingBusiness Ac...
# 0       6057868  schema:Accommodation schema:LodgingBusiness Ac...
# 0       6048874  schema:Accommodation schema:Hotel schema:Lodgi...
# 0       6057858  schema:Accommodation schema:LodgingBusiness Ac...
# 0       6051476  schema:Accommodation schema:BedAndBreakfast sc...
# 0       6048879  schema:Accommodation schema:Hotel schema:Lodgi...
# 0       6057852  schema:Accommodation schema:LodgingBusiness Ac...
# 0       6051680  schema:Accommodation schema:BedAndBreakfast sc...
# 0       6051474  schema:Accommodation schema:LodgingBusiness Ac...
# 0       6057871  schema:Accommodation schema:LodgingBusiness Ac...
# 0       6048885  schema:Accommodation schema:FoodEstablishment ...
# 0       6051532  schema:Accommodation schema:LodgingBusiness Ac...
# 0       6057879  schema:Accommodation schema:LodgingBusiness Ac...
# 0       6051625  schema:Accommodation schema:LodgingBusiness Ac...
# 0       6057863  schema:Accommodation schema:LodgingBusiness Ac...
# 0       6048868  schema:Accommodation schema:FoodEstablishment ...
# 0       6406205  schema:Accommodation schema:LodgingBusiness Ac...
# 0       6057855  schema:Accommodation schema:LodgingBusiness Ac...
# 0       6057870  schema:Accommodation schema:LodgingBusiness Ac...
# 0       6048884  schema:Accommodation schema:FoodEstablishment ...
# 0       6051533  schema:Accommodation schema:LodgingBusiness Ac...
# 0       6057853  schema:Accommodation schema:LodgingBusiness Ac...
# 0       6048881  schema:Accommodation schema:FoodEstablishment ...
# 0         89428  schema:Accommodation schema:LodgingBusiness Ac...
# 0         86970  schema:Accommodation schema:LodgingBusiness Ac...
# 0         60246  schema:Accommodation schema:LodgingBusiness Ac...
# 0         78726  schema:Accommodation schema:LodgingBusiness Ac...
# 0         57024  schema:Accommodation schema:LodgingBusiness Ac...
# 0         14821  schema:Accommodation schema:LodgingBusiness Ac...
# 0         60193  schema:Accommodation schema:LodgingBusiness Ac...
# 0        100860  schema:Accommodation schema:LodgingBusiness Ac...
# 0         15399  schema:Accommodation schema:LodgingBusiness Ac...
# 0         79462  schema:Accommodation schema:LodgingBusiness Ac...
# 0         13405  schema:Accommodation schema:LodgingBusiness Ac...
# 0         73725  schema:Accommodation schema:LodgingBusiness Ac...
# 0         89494  schema:Accommodation schema:LodgingBusiness Ac...
#
#                                      rdfs:comment.fr  \
# 0  L’hôtel LA TOUR DES LYS vous accueille depuis ...
# 0  Un hôtel de charme 3 étoiles, dans un château ...
# 0  Magda en charge de la Direction ainsi que tout...
# 0  Des chambres d’hôtes à la ferme à Solre-le-Châ...
# 0  Camping est situé au calme en lisière de la fo...
# 0  Dans le joli village de Ferrière la Petite, Cl...
# 0  Offrez-vous une parenthèse paisible dans cet é...
# 0  Janine vous accueille dans son gîte situé dans...
# 0  En plein bocage avesnois, vous serez accueilli...
# 0  L'hôtel est situé à 200 m de la Gare, Idéal po...
# 0  En plein cœur du bocage avesnois, à Prisches, ...
# 0  Ce camping de 100 emplacements offre de nombre...
# 0  Roselyne, Bruno et Guillaume vous accueillent ...
# 0        Camping situé en plein coeur de l'Avesnois.
# 0  Profitez de ce camping naturiste pour vous res...
# 0  L'Étape de la Pierre Bleue abrite le camping L...
# 0  Hôtel 3 étoiles situé en lisière de la forêt e...
# 0  Situé au coeur de la cité fortifiée du Quesnoy...
# 0  Située au cœur du Parc Naturel Régional de l’A...
# 0  L'hôtel Première Classe de Maubeuge vous propo...
# 0                      Ressourcez-vous au bol d’air.
# 0  Une ferme avesnoise, avec ânes et moutons, vou...
# 0  Janine et son mari vous accueillent dans un an...
# 0  Le camping municipal est situé dans le petit v...
# 0  L'hôtel "Les Charmilles de Mormal"  vous accue...
# 0  Au bout d’un chemin, en plein cœur du Parc Nat...
# 0  Camping 3* situé dans un cadre verdoyant à pro...
# 0  À quelques pas de la frontière belge, Karine v...
# 0  Envie de passer des vacances dans la bonne hum...
# 0  Le BEST WESTERN l'Atelier 117 Hotel & Restaura...
# 0  Dans l'ancienne gare de Ferrière la Grande ent...
# 0  Camping à la ferme à 8 minutes du Val Joly, po...
# 0  Le camping se situe dans un lieu boisé, bordé ...
# 0  La famille Herriche vous accueille dans leur h...
# 0  Au bout d’un chemin, en plein cœur du Parc Nat...
# 0  Le camping est situé dans le parc naturel régi...
# 0  Toute l'équipe vous accueille dans un cadre so...
# 0                                               None
# 0                                               None
# 0                                               None
# 0                                               None
# 0                                               None
# 0                                               None
# 0                                               None
# 0                                               None
# 0                                               None
# 0  Appartement meublé très confortable, spacieux ...
# 0                                               None
# 0                                               None
# 0                                               None
#
#                                    dc:description.fr                     0  \
# 0                                               None  schema:Accommodation
# 0                                               None  schema:Accommodation
# 0                                               None  schema:Accommodation
# 0                                               None  schema:Accommodation
# 0                                               None  schema:Accommodation
# 0                                               None  schema:Accommodation
# 0                                               None  schema:Accommodation
# 0                                               None  schema:Accommodation
# 0                                               None  schema:Accommodation
# 0                                               None  schema:Accommodation
# 0                                               None  schema:Accommodation
# 0                                               None  schema:Accommodation
# 0                                               None  schema:Accommodation
# 0                                               None  schema:Accommodation
# 0                                               None  schema:Accommodation
# 0                                               None  schema:Accommodation
# 0                                               None  schema:Accommodation
# 0                                               None  schema:Accommodation
# 0                                               None  schema:Accommodation
# 0                                               None  schema:Accommodation
# 0                                               None  schema:Accommodation
# 0                                               None  schema:Accommodation
# 0                                               None  schema:Accommodation
# 0                                               None  schema:Accommodation
# 0                                               None  schema:Accommodation
# 0                                               None  schema:Accommodation
# 0                                               None  schema:Accommodation
# 0                                               None  schema:Accommodation
# 0                                               None  schema:Accommodation
# 0                                               None  schema:Accommodation
# 0                                               None  schema:Accommodation
# 0                                               None  schema:Accommodation
# 0                                               None  schema:Accommodation
# 0                                               None  schema:Accommodation
# 0                                               None  schema:Accommodation
# 0                                               None  schema:Accommodation
# 0                                               None  schema:Accommodation
# 0  Profitez d'un gîte en plein nature pour un séj...  schema:Accommodation
# 0  Gite dans maison des proprio ( séparée en 2) a...  schema:Accommodation
# 0  C’est un choix idéal pour les jeunes mariés ou...  schema:Accommodation
# 0  Appartement T2, 35 m2 en rez-de-chaussée , ave...  schema:Accommodation
# 0  Situé à Berck-sur-Mer, le Miny Park vous accue...  schema:Accommodation
# 0  Le Najeti Hotel du Golf, établissement moderne...  schema:Accommodation
# 0  Envie de vous évadez le temps d'un weekend au ...  schema:Accommodation
# 0                                 Gîte à la campagne  schema:Accommodation
# 0         Etablissement fermé de novembre à février.  schema:Accommodation
# 0  Location appartement de tourisme 6 couchages s...  schema:Accommodation
# 0  Venez découvrir notre gîte ! \nAu rez de chaus...  schema:Accommodation
# 0  Petits et grands pourront découvrir les animau...  schema:Accommodation
# 0  Hyper-centre, des vacances paisibles, entièrem...  schema:Accommodation
#
#                           1                       2                        3  \
# 0  schema:FoodEstablishment            schema:Hotel   schema:LodgingBusiness
# 0  schema:FoodEstablishment            schema:Hotel   schema:LodgingBusiness
# 0              schema:Hotel  schema:LodgingBusiness            Accommodation
# 0    schema:BedAndBreakfast  schema:LodgingBusiness            Accommodation
# 0    schema:LodgingBusiness           Accommodation                  Camping
# 0    schema:LodgingBusiness           Accommodation          PlaceOfInterest
# 0              schema:Hotel  schema:LodgingBusiness            Accommodation
# 0    schema:LodgingBusiness           Accommodation          PlaceOfInterest
# 0    schema:BedAndBreakfast  schema:LodgingBusiness            Accommodation
# 0              schema:Hotel  schema:LodgingBusiness            Accommodation
# 0    schema:LodgingBusiness           Accommodation          PlaceOfInterest
# 0    schema:LodgingBusiness           Accommodation                  Camping
# 0    schema:LodgingBusiness           Accommodation                  Camping
# 0    schema:LodgingBusiness           Accommodation                  Camping
# 0    schema:LodgingBusiness           Accommodation                  Camping
# 0    schema:LodgingBusiness           Accommodation                  Camping
# 0              schema:Hotel  schema:LodgingBusiness            Accommodation
# 0    schema:LodgingBusiness           Accommodation                  Camping
# 0    schema:BedAndBreakfast  schema:LodgingBusiness            Accommodation
# 0              schema:Hotel  schema:LodgingBusiness            Accommodation
# 0    schema:LodgingBusiness           Accommodation                  Camping
# 0    schema:BedAndBreakfast  schema:LodgingBusiness            Accommodation
# 0    schema:LodgingBusiness           Accommodation          PlaceOfInterest
# 0    schema:LodgingBusiness           Accommodation                  Camping
# 0  schema:FoodEstablishment            schema:Hotel   schema:LodgingBusiness
# 0    schema:LodgingBusiness           Accommodation          PlaceOfInterest
# 0    schema:LodgingBusiness           Accommodation                  Camping
# 0    schema:LodgingBusiness           Accommodation          PlaceOfInterest
# 0    schema:LodgingBusiness           Accommodation                  Camping
# 0  schema:FoodEstablishment            schema:Hotel   schema:LodgingBusiness
# 0    schema:LodgingBusiness           Accommodation  CollectiveAccommodation
# 0    schema:LodgingBusiness           Accommodation                  Camping
# 0    schema:LodgingBusiness           Accommodation                  Camping
# 0  schema:FoodEstablishment            schema:Hotel   schema:LodgingBusiness
# 0    schema:LodgingBusiness           Accommodation          PlaceOfInterest
# 0    schema:LodgingBusiness           Accommodation                  Camping
# 0  schema:FoodEstablishment            schema:Hotel   schema:LodgingBusiness
# 0    schema:LodgingBusiness           Accommodation          PlaceOfInterest
# 0    schema:LodgingBusiness           Accommodation          PlaceOfInterest
# 0    schema:LodgingBusiness           Accommodation          PlaceOfInterest
# 0    schema:LodgingBusiness           Accommodation          PlaceOfInterest
# 0    schema:LodgingBusiness           Accommodation    CampingAndCaravanning
# 0    schema:LodgingBusiness           Accommodation               HotelTrade
# 0    schema:LodgingBusiness           Accommodation          PlaceOfInterest
# 0    schema:LodgingBusiness           Accommodation          PlaceOfInterest
# 0    schema:LodgingBusiness           Accommodation          PlaceOfInterest
# 0    schema:LodgingBusiness           Accommodation          PlaceOfInterest
# 0    schema:LodgingBusiness           Accommodation          PlaceOfInterest
# 0    schema:LodgingBusiness           Accommodation          PlaceOfInterest
# 0    schema:LodgingBusiness           Accommodation          PlaceOfInterest
#
#                        4                    5                          6  \
# 0      schema:Restaurant        Accommodation          FoodEstablishment
# 0      schema:Restaurant        Accommodation          FoodEstablishment
# 0                  Hotel           HotelTrade            PlaceOfInterest
# 0             Guesthouse      PlaceOfInterest            PointOfInterest
# 0  CampingAndCaravanning      PlaceOfInterest            PointOfInterest
# 0        PointOfInterest  RentalAccommodation  SelfCateringAccommodation
# 0                  Hotel           HotelTrade            PlaceOfInterest
# 0        PointOfInterest  RentalAccommodation  SelfCateringAccommodation
# 0             Guesthouse      PlaceOfInterest            PointOfInterest
# 0                  Hotel           HotelTrade            PlaceOfInterest
# 0        PointOfInterest  RentalAccommodation  SelfCateringAccommodation
# 0  CampingAndCaravanning      PlaceOfInterest            PointOfInterest
# 0  CampingAndCaravanning      PlaceOfInterest            PointOfInterest
# 0  CampingAndCaravanning      PlaceOfInterest            PointOfInterest
# 0  CampingAndCaravanning      PlaceOfInterest            PointOfInterest
# 0  CampingAndCaravanning      PlaceOfInterest            PointOfInterest
# 0                  Hotel           HotelTrade            PlaceOfInterest
# 0  CampingAndCaravanning      PlaceOfInterest            PointOfInterest
# 0             Guesthouse      PlaceOfInterest            PointOfInterest
# 0                  Hotel           HotelTrade            PlaceOfInterest
# 0  CampingAndCaravanning      PlaceOfInterest            PointOfInterest
# 0             Guesthouse      PlaceOfInterest            PointOfInterest
# 0        PointOfInterest  RentalAccommodation  SelfCateringAccommodation
# 0  CampingAndCaravanning      PlaceOfInterest            PointOfInterest
# 0      schema:Restaurant        Accommodation          FoodEstablishment
# 0        PointOfInterest  RentalAccommodation  SelfCateringAccommodation
# 0  CampingAndCaravanning      PlaceOfInterest            PointOfInterest
# 0        PointOfInterest  RentalAccommodation  SelfCateringAccommodation
# 0  CampingAndCaravanning      PlaceOfInterest            PointOfInterest
# 0      schema:Restaurant        Accommodation          FoodEstablishment
# 0           GroupLodging      PlaceOfInterest            PointOfInterest
# 0  CampingAndCaravanning      PlaceOfInterest            PointOfInterest
# 0  CampingAndCaravanning      PlaceOfInterest            PointOfInterest
# 0      schema:Restaurant        Accommodation          FoodEstablishment
# 0        PointOfInterest  RentalAccommodation  SelfCateringAccommodation
# 0  CampingAndCaravanning      PlaceOfInterest            PointOfInterest
# 0      schema:Restaurant        Accommodation          FoodEstablishment
# 0        PointOfInterest  RentalAccommodation                       None
# 0        PointOfInterest  RentalAccommodation                       None
# 0        PointOfInterest  RentalAccommodation                       None
# 0        PointOfInterest  RentalAccommodation                       None
# 0        PlaceOfInterest      PointOfInterest                       None
# 0        PlaceOfInterest      PointOfInterest                       None
# 0        PointOfInterest  RentalAccommodation                       None
# 0        PointOfInterest  RentalAccommodation                       None
# 0        PointOfInterest  RentalAccommodation                       None
# 0        PointOfInterest  RentalAccommodation                       None
# 0        PointOfInterest  RentalAccommodation                       None
# 0        PointOfInterest  RentalAccommodation                       None
# 0        PointOfInterest  RentalAccommodation                       None
#
#                       7                8           9               10  \
# 0                 Hotel  HotelRestaurant  HotelTrade  PlaceOfInterest
# 0                 Hotel  HotelRestaurant  HotelTrade  PlaceOfInterest
# 0       PointOfInterest             None        None             None
# 0   RentalAccommodation             None        None             None
# 0                  None             None        None             None
# 0                  None             None        None             None
# 0       PointOfInterest             None        None             None
# 0                  None             None        None             None
# 0   RentalAccommodation             None        None             None
# 0       PointOfInterest             None        None             None
# 0                  None             None        None             None
# 0                  None             None        None             None
# 0                  None             None        None             None
# 0                  None             None        None             None
# 0                  None             None        None             None
# 0                  None             None        None             None
# 0       PointOfInterest             None        None             None
# 0                  None             None        None             None
# 0   RentalAccommodation             None        None             None
# 0       PointOfInterest             None        None             None
# 0                  None             None        None             None
# 0   RentalAccommodation             None        None             None
# 0                  None             None        None             None
# 0                  None             None        None             None
# 0                 Hotel  HotelRestaurant  HotelTrade  PlaceOfInterest
# 0                  None             None        None             None
# 0                  None             None        None             None
# 0                  None             None        None             None
# 0                  None             None        None             None
# 0                 Hotel  HotelRestaurant  HotelTrade  PlaceOfInterest
# 0  StopOverOrGroupLodge             None        None             None
# 0                  None             None        None             None
# 0                  None             None        None             None
# 0                 Hotel  HotelRestaurant  HotelTrade  PlaceOfInterest
# 0                  None             None        None             None
# 0                  None             None        None             None
# 0                 Hotel  HotelRestaurant  HotelTrade  PlaceOfInterest
# 0                  None             None        None             None
# 0                  None             None        None             None
# 0                  None             None        None             None
# 0                  None             None        None             None
# 0                  None             None        None             None
# 0                  None             None        None             None
# 0                  None             None        None             None
# 0                  None             None        None             None
# 0                  None             None        None             None
# 0                  None             None        None             None
# 0                  None             None        None             None
# 0                  None             None        None             None
# 0                  None             None        None             None
#
#                 11          12
# 0  PointOfInterest  Restaurant
# 0  PointOfInterest  Restaurant
# 0             None        None
# 0             None        None
# 0             None        None
# 0             None        None
# 0             None        None
# 0             None        None
# 0             None        None
# 0             None        None
# 0             None        None
# 0             None        None
# 0             None        None
# 0             None        None
# 0             None        None
# 0             None        None
# 0             None        None
# 0             None        None
# 0             None        None
# 0             None        None
# 0             None        None
# 0             None        None
# 0             None        None
# 0             None        None
# 0  PointOfInterest  Restaurant
# 0             None        None
# 0             None        None
# 0             None        None
# 0             None        None
# 0  PointOfInterest  Restaurant
# 0             None        None
# 0             None        None
# 0             None        None
# 0  PointOfInterest  Restaurant
# 0             None        None
# 0             None        None
# 0  PointOfInterest  Restaurant
# 0             None        None
# 0             None        None
# 0             None        None
# 0             None        None
# 0             None        None
# 0             None        None
# 0             None        None
# 0             None        None
# 0             None        None
# 0             None        None
# 0             None        None
# 0             None        None
# 0             None        None

# %% [markdown]
# ## préparation de la colonne rdfs:comment.fr pour son utilisation dans le ML

# %%
import nltk
nltk.download('popular')
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package omw to /Users/julien/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /Users/julien/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# True

# %%
import spacy
import string
from nltk.tokenize.punkt import FreqDist
import re

nlp = spacy.load('fr_core_news_lg')

def clean(sentence):
    """
    This function 'clean' takes a single input 'sentence', a string, and performs several operations to 'clean' the text.

    These operations are:
    1. Removing punctuation using a regular expression.
    2. Removing accent
    3. Tokenizing the sentence into individual words.
    4. Removing English stopwords.
    5. Joining the remaining words back into a sentence.
    6. Lemmatizing the sentence using the Spacy English language model.

    The function returns the cleaned, lemmatized sentence as a single string.
    """
    # Retrait de la ponctuation
    sentence_no_punct = re.sub(r"[^\w\s]", "", sentence)
    
    # Retrait des accents
    # Définition du dictionnaire pour remplacer les caratères
    dict_replacement = {"à": "a", "â": "a", "ä": "a", "é": "e", "è": "e", "ê": "e", "ë": "e",
                    "î": "i", "ï": "i", "ô": "o", "ö": "o", "ù": "o", "û": "u", "ü": "u"}

    # Création d'une fonction qui permet de changer les caractères à accent
    # La fonction reçoit la lettre de la correspondance trouvée
    def remplacer(match):
        # La lettre correspondante au regex est extraite
        lettre = match.group(0)
        #Renvoi la valeur correspondante du dictionnaire si celle ci est présente
        return dict_replacement.get(lettre)

    sentence_no_punct_no_accent = re.sub(r"[àâäéèêëîïôöùûü]", remplacer, sentence_no_punct)

    # Transformation de la phrase en tokens
    sentence_no_punct_no_accent = nltk.word_tokenize(sentence_no_punct_no_accent.lower())

    # Liste des stopwords à retirer
    stop_words = set(nltk.corpus.stopwords.words("french"))

    # Récupération des tokens sans stopwords
    sentence_clean = []
    for words in sentence_no_punct_no_accent:
        if words not in stop_words:
            sentence_clean.append(words)

    # Transformer la liste en chaine de caratères
    sentence_clean_str = ' '.join(sentence_clean)

    # Utilisation de spacy
    sentence_clean_str_spacy = nlp(sentence_clean_str)

    sentence_clean_str_spacy_lemmatized = [token.lemma_ for token in sentence_clean_str_spacy]

    return ' '.join(sentence_clean_str_spacy_lemmatized)

dfs_verif["rdfs:comment.fr"] = dfs_verif["rdfs:comment.fr"].apply(clean)

# %%
dfs_verif["rdfs:comment.fr"][9]
# Out:
# "L'hôtel est situé à 200 m de la Gare, Idéal pour vos séjours professionnels, sportifs ou en famille"

# %% [markdown]
# # Création d'un data frame contenant les informations des restaurants pour le NLP et le ML   POUR PLUS TARD

# %%
# Variable contenant le ficher json de "base" où je peux récupérer un mroceau du chemin pour chacun des hotels
url_resto = "https://raw.githubusercontent.com/JulienMhtt/Projets/main/Projet_3/flux_restaurants_hdf/index.json"
# Requetage de la base de données
r_resto = requests.get(url_resto)
# Variable contenant le fichier json (une liste)
data_resto = r_resto.json()

# Création d'un data frame vite pour recevoir les données des hotels par la suite
df_all_resto = pd.DataFrame()

# Création d'une liste pour stocker les differents data frame récupéré dans la boucle
dfs_resto = []

# Initialisation d'une boucle de longeur 10 pour obtenir un échantillon
for file in range(10):
    # variable contenant la base du chemin vers la base de donnée
    base = "https://raw.githubusercontent.com/JulienMhtt/Projets/main/Projet_3/flux_restaurants_hdf/objects/"
    # url complète composé de la base de l'url et de la seconde partie venant de data
    url_file = base + data_resto[file]["file"]
    # Requetage de la base de données
    r_file = requests.get(url_file)
    # Variable contenant le fichier json (un dictionnaire)
    data_file = r_file.json()
    # Variable contenant le fichier json tranformé en data frame
    df = pd.json_normalize(data_file)[["dc:identifier", "@type", "rdfs:comment.fr"]]
    df["shortDescription.fr"] = pd.json_normalize(data_file, record_path="hasDescription")[["shortDescription.fr"]]
    # Ajout du dataframe à la liste de stockage
    dfs_resto.append(df)

# Fonction pour extraire les chaines de caractères des listes    
def extraction(valeur):
    if type(valeur) == list:
        valeur = ' '.join(valeur)  # joindre les éléments de la liste avec un espace
        return valeur
    else:
        return valeur
    
# Concaténation de la liste contenant tous les data frame et le data frame vide
df_all_resto = pd.concat(dfs_resto)
df_all_resto = df_all_resto.applymap(extraction)
df_all_resto
# Out:
#   dc:identifier                                              @type  \
# 0       6048677  schema:FoodEstablishment FoodEstablishment Pla...
# 0       6048787  schema:FoodEstablishment FoodEstablishment Pla...
# 0       6048799  schema:FoodEstablishment FoodEstablishment Pla...
# 0       6048789  schema:FoodEstablishment FoodEstablishment Pla...
# 0       6048763  schema:FoodEstablishment FoodEstablishment Pla...
# 0       6048673  schema:FoodEstablishment FoodEstablishment Pla...
# 0       6048784  schema:FoodEstablishment FoodEstablishment Pla...
# 0       6048709  schema:FoodEstablishment FoodEstablishment Pla...
# 0       6048700  schema:FoodEstablishment FoodEstablishment Pla...
# 0       6048882  schema:Accommodation schema:FoodEstablishment ...
#
#                                      rdfs:comment.fr  \
# 0  Poussez la porte de cet estaminet, où Dominiqu...
# 0  Mikael vous accueille dans son établissement e...
# 0  Dans un écrin vaste et très chaleureux, Fabric...
# 0  Une ferme-auberge au cadre typique en plein cœ...
# 0  Idéalement située au cœur de la station du Val...
# 0  Géraldine vous accueille au cœur de la Station...
# 0  Les Vergers Tellier vous proposent de venir pa...
# 0  L’Hostellerie du marché vous accueille dans le...
# 0  Dans la « rue commerçante » du ValJoly, idéale...
# 0  L’hôtel LA TOUR DES LYS vous accueille depuis ...
#
#                                  shortDescription.fr
# 0  Poussez la porte de cet estaminet, où Dominiqu...
# 0  Mikael vous accueille dans son établissement e...
# 0  Dans un écrin vaste et très chaleureux, Fabric...
# 0  Une ferme-auberge au cadre typique en plein cœ...
# 0  Idéalement située au cœur de la station du Val...
# 0  Géraldine vous accueille au cœur de la Station...
# 0  Les Vergers Tellier vous proposent de venir pa...
# 0  L’Hostellerie du marché vous accueille dans le...
# 0  Dans la « rue commerçante » du ValJoly, idéale...
# 0  L’hôtel LA TOUR DES LYS vous accueille depuis ...
